# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
true_masks = np.load("true_masks.npy")

# %%
true_masks.shape
# Out:
# (9, 256, 256)

# %%
plt.imshow(true_masks[0])

# %%
plt.imshow(true_masks[1])

# %%
plt.imshow(true_masks[2])

# %%
pred_masks = np.load("pred_masks.npy")

# %%
plt.imshow(true_masks.sum(axis=0))

# %%
plt.imshow(pred_masks.sum(axis=0))

# %%
plt.imshow(pred_masks[0])

# %%
plt.imshow(pred_masks[2])

# %%
plt.imshow(pred_masks[3])

# %%
plt.imshow(pred_masks[4])

# %%
plt.imshow(pred_masks[5])

# %%
plt.imshow(pred_masks[6])

# %%
plt.imshow(pred_masks[7])

# %%
plt.imshow(pred_masks[8])

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1725/3208370906.py in <module>
# ----> 1 plt.imshow(pred_masks[9])
#
# IndexError: index 9 is out of bounds for axis 0 with size 9
