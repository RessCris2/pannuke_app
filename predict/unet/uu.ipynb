# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
seg_logits= np.load("seg_logits.npy")

# %%
seg_logits.shape
# Out:
# (4, 1000, 1000)

# %%
torch.softmax(torch.tensor(seg_logits), dim=1).sum(axis=1)
# Out:
# tensor([[1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000],
#         [1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000],
#         [1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000],
#         [1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000]])

# %%
torch.softmax(torch.tensor(seg_logits), dim=0).shape
# Out:
# torch.Size([4, 1000, 1000])

# %%
prob_map= np.load("prob_map.npy")

# %%
plt.imshow(prob_map)

# %%
prob_map
# Out:
# array([[0.54486096, 0.54486096, 0.5514611 , ..., 0.509505  , 0.50085664,
#         0.50085664],
#        [0.54486096, 0.54486096, 0.5514611 , ..., 0.509505  , 0.50085664,
#         0.50085664],
#        [0.5452229 , 0.5452229 , 0.5535462 , ..., 0.5140769 , 0.5049656 ,
#         0.5049656 ],
#        ...,
#        [0.5125445 , 0.5125445 , 0.52746147, ..., 0.47456267, 0.4694274 ,
#         0.4694274 ],
#        [0.49568626, 0.49568626, 0.5095264 , ..., 0.47003403, 0.46719018,
#         0.46719018],
#        [0.49568626, 0.49568626, 0.5095264 , ..., 0.47003403, 0.46719018,
#         0.46719018]], dtype=float32)

# %%
label = np.load("ar_label.npy")

# %%
label
# Out:
# array([[  1,   1,   1, ...,  37,  37,  37],
#        [  1,   1,   1, ...,  37,  37,  37],
#        [  1,   1,   1, ...,  37,  37,  37],
#        ...,
#        [929, 929, 929, ...,   0,   0,   0],
#        [  0,   0, 929, ...,   0,   0,   0],
#        [  0,   0, 929, ...,   0,   0,   0]])

# %%
plt.imshow(label)

# %%
label = remove_small_objects(label, min_size=100, connectivity=1)

# %%
import numpy as np

# 示例输入数组
inst_label = np.array([1,1, 2, 2, 3, 3, 3, 7,8])

# 使用 np.bincount 计算频次
counts = np.bincount(inst_label)

print(counts)
# Out:
# [0 2 2 3 0 0 0 1 1]

# %%
np.argmax(counts)
# Out:
# 3
