# %%
from mmengine import Config
import os.path as osp

# %%
cfg = Config.fromfile("./consep_config.py")
print(cfg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_825/228620382.py in <module>
# ----> 1 cfg = Config.fromfile("./consep_config.py")
#       2 print(cfg)
#
# ~/miniconda3/lib/python3.8/site-packages/mmengine/config/config.py in fromfile(filename, use_predefined_variables, import_custom_modules, use_environment_variables)
#     176         """
#     177         filename = str(filename) if isinstance(filename, Path) else filename
# --> 178         cfg_dict, cfg_text, env_variables = Config._file2dict(
#     179             filename, use_predefined_variables, use_environment_variables)
#     180         if import_custom_modules and cfg_dict.get('custom_imports', None):
#
# ~/miniconda3/lib/python3.8/site-packages/mmengine/config/config.py in _file2dict(filename, use_predefined_variables, use_environment_variables)
#     515                     codes = ast.parse(f.read())
#     516                     codes = RemoveAssignFromAST(BASE_KEY).visit(codes)
# --> 517                 codeobj = compile(codes, '', mode='exec')
#     518                 # Support load global variable in nested function of the
#     519                 # config.
#
# ValueError: empty body on If

# %%
from mmdet.apis import DetInferencer

# 初始化模型
inferencer = DetInferencer(model='./consep_config.py',
                          weights="./model_data/epoch_80.pth",
                          device='cpu',
                           out= 'results.pkl'
                          )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_825/2498322348.py in <module>
#       2
#       3 # 初始化模型
# ----> 4 inferencer = DetInferencer(model='./consep_config.py',
#       5                           weights="./model_data/epoch_80.pth",
#       6                           device='cpu',
#
# TypeError: __init__() got an unexpected keyword argument 'out'

# %%
# 推理示例图片
if osp.exists("/home/pannuke_app/"):
    _img_path = "/home/pannuke_app/train/datasets/CoNSeP/Train/Images/train_1.png"
else:
    img_path = '/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/Train/Images/train_1.png'

res  = inferencer(inputs = img_path , 
           show=True,
           pred_score_thr=0.05,
           draw_pred=True,
           out_dir='./',
           return_datasample=False
          )
# Out:
# Output()
# /root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their
# associated APIs are an experimental feature and subject to change. Please do not use them for anything important
# until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /root/miniconda3/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:757: UserWarning: Warning: The
# bbox is out of bounds, the drawn bbox may not be in the image
#   warnings.warn(
# /root/miniconda3/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:828: UserWarning: Warning: The
# polygon is out of bounds, the drawn polygon may not be in the image
#   warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
res['predictions'][0].keys()
# Out:
# dict_keys(['bboxes', 'labels', 'scores', 'masks'])

# %%
res  = inferencer(inputs = img_path , 
           show=True,
           pred_score_thr=0.05,
           draw_pred=True,
           out_dir='./',
           return_datasample=False,
            no_save_pred=False
          )
# Out:
# Output()
# /root/miniconda3/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:757: UserWarning: Warning: The
# bbox is out of bounds, the drawn bbox may not be in the image
#   warnings.warn(
# /root/miniconda3/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:828: UserWarning: Warning: The
# polygon is out of bounds, the drawn polygon may not be in the image
#   warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import json

# Paths to the files 获取指定图片的数据
gt_json_path = '/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/Train/annotations.json'  # Ground truth annotations
# Initialize COCO ground truth API
coco_gt = COCO(gt_json_path)
# Initialize COCO detections API
coco_dt = coco_gt.loadRes(detections_json_path)

detections_json_path = 'path/to/your/detections.json'  # Detection results from mmdetection

# Initialize COCO ground truth API
coco_gt = COCO(gt_json_path)

# Initialize COCO detections API
coco_dt = coco_gt.loadRes(detections_json_path)

# COCO Evaluator
coco_eval = COCOeval(coco_gt, coco_dt, 'bbox')

# Evaluate on a subset of the data, e.g., the validation set. If you want to evaluate all the data, just do not specify the ids.
# coco_eval.params.imgIds = validation_img_ids # Use the ids of your validation images here

# Run Evaluation
coco_eval.evaluate()
coco_eval.accumulate()
coco_eval.summarize()

# The results will be printed out, and you can analyze them.

# %%
# Initialize COCO ground truth API
coco_gt = COCO(gt_json_path)
# Out:
# loading annotations into memory...
# Done (t=0.28s)
# creating index...
# index created!

# %%
# Initialize COCO detections API
coco_dt = coco_gt.loadRes(detections_json_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_825/2600197346.py in <module>
#       1 # Initialize COCO detections API
# ----> 2 coco_dt = coco_gt.loadRes(detections_json_path)
#
# NameError: name 'detections_json_path' is not defined

# %%
detections_json_path = 'path/to/your/detections.json'  # Detection results from mmdetection

# Initialize COCO ground truth API
coco_gt = COCO(gt_json_path)

# Initialize COCO detections API
coco_dt = coco_gt.loadRes(detections_json_path)

# COCO Evaluator
coco_eval = COCOeval(coco_gt, coco_dt, 'bbox')

# Evaluate on a subset of the data, e.g., the validation set. If you want to evaluate all the data, just do not specify the ids.
# coco_eval.params.imgIds = validation_img_ids # Use the ids of your validation images here

# Run Evaluation
coco_eval.evaluate()
coco_eval.accumulate()
coco_eval.summarize()

# The results will be printed out, and you can analyze them.

# %%
# !python test.py
# Out:
# 11/08 14:42:03 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 1049552465
#     GPU 0: NVIDIA RTX A5000
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.1, V11.1.105
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.9.0+cu111
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.1.2 (Git Hash 98be7e8afa711dc9b66c8ff3504129cb82013cdb)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.1
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.0.5
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.9.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.10.0+cu111
#     OpenCV: 4.7.0
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/08 14:42:04 - mmengine - INFO - Config:
# model = dict(
#     type='MaskRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=False,
#         pad_mask=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=4,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#         mask_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=14, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         mask_head=dict(
#             type='FCNMaskHead',
#             num_convs=4,
#             in_channels=256,
#             conv_out_channels=256,
#             num_classes=4,
#             loss_mask=dict(
#                 type='CrossEntropyLoss', use_mask=True, loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             mask_size=28,
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=2000,
#             max_per_img=1500,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=1000,
#             mask_thr_binary=0.5)))
# dataset_type = 'CocoDataset'
# data_root = '/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/'
# metainfo = dict(
#     classes=('Inflammatory', 'Healthy_epithelial', 'Epithelial',
#              'Spindle-shaped'),
#     palette=[(120, 120, 60), (20, 120, 160), (72, 100, 60), (111, 67, 60)])
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(256, 256)),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=4,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/',
#         metainfo=dict(
#             classes=('Inflammatory', 'Healthy_epithelial', 'Epithelial',
#                      'Spindle-shaped'),
#             palette=[(120, 120, 60), (20, 120, 160), (72, 100, 60),
#                      (111, 67, 60)]),
#         ann_file='Train/annotations.json',
#         data_prefix=dict(img='Train/Images/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(256, 256)),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackDetInputs')
#         ],
#         backend_args=None))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=1,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/',
#         metainfo=dict(
#             classes=('Inflammatory', 'Healthy_epithelial', 'Epithelial',
#                      'Spindle-shaped'),
#             palette=[(120, 120, 60), (20, 120, 160), (72, 100, 60),
#                      (111, 67, 60)]),
#         ann_file='Test/annotations.json',
#         data_prefix=dict(img='Test/Images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None,
#         indices=3))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=1,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/',
#         metainfo=dict(
#             classes=('Inflammatory', 'Healthy_epithelial', 'Epithelial',
#                      'Spindle-shaped'),
#             palette=[(120, 120, 60), (20, 120, 160), (72, 100, 60),
#                      (111, 67, 60)]),
#         ann_file='Test/annotations.json',
#         data_prefix=dict(img='Test/Images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None,
#         indices=3))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/Test/annotations.json',
#     metric=['bbox', 'segm'],
#     format_only=False,
#     backend_args=None,
#     outfile_prefix=
#     '/root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/work_dirs/test')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/Test/annotations.json',
#     metric=['bbox', 'segm'],
#     format_only=False,
#     backend_args=None,
#     outfile_prefix=
#     '/root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/work_dirs/test')
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=100, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=40,
#         by_epoch=True,
#         milestones=[8, 11],
#         gamma=0.1)
# ]
# optim_wrapper = dict(
#     type='OptimWrapper', optimizer=dict(type='Adam', lr=0.001))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=1),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='WandbVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='WandbVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=1, by_epoch=True)
# log_level = 'DEBUG'
# load_from = '/root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/model_data/epoch_90.pth'
# resume = False
# launcher = 'none'
# work_dir = './work_dirs/consep_config'
#
# 11/08 14:42:04 - mmengine - DEBUG - Modules of mmdet's visualizer registry have been automatically imported from mmdet.visualization
# 11/08 14:42:04 - mmengine - DEBUG - Get class `DetLocalVisualizer` from "visualizer" registry in "mmdet"
# 11/08 14:42:04 - mmengine - DEBUG - Modules of mmdet's vis_backend registry have been automatically imported from mmdet.visualization
# 11/08 14:42:04 - mmengine - DEBUG - Get class `WandbVisBackend` from "vis_backend" registry in "mmengine"
# 11/08 14:42:04 - mmengine - DEBUG - An `WandbVisBackend` instance is built from registry, and its implementation can be found in mmengine.visualization.vis_backend
# 11/08 14:42:04 - mmengine - DEBUG - An `DetLocalVisualizer` instance is built from registry, and its implementation can be found in mmdet.visualization.local_visualizer
# 11/08 14:42:04 - mmengine - DEBUG - Attribute `_env_initialized` is not defined in <class 'mmengine.visualization.vis_backend.WandbVisBackend'> or `<class 'mmengine.visualization.vis_backend.WandbVisBackend'>._env_initialized is False, `_init_env` will be called and <class 'mmengine.visualization.vis_backend.WandbVisBackend'>._env_initialized will be set to True
# wandb: Currently logged in as: weifeiouyang (weifei). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/work_dirs/consep_config/20231108_144202/vis_data/wandb/run-20231108_144206-hwuiw8kc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run easy-dream-19
# wandb: ⭐️ View project at https://wandb.ai/weifei/pannuke_app-train_mask_rcnn_consep
# wandb: 🚀 View run at https://wandb.ai/weifei/pannuke_app-train_mask_rcnn_consep/runs/hwuiw8kc
# 11/08 14:42:09 - mmengine - DEBUG - Modules of mmdet's model registry have been automatically imported from mmdet.models
# 11/08 14:42:09 - mmengine - DEBUG - Get class `MaskRCNN` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `DetDataPreprocessor` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `DetDataPreprocessor` instance is built from registry, and its implementation can be found in mmdet.models.data_preprocessors.data_preprocessor
# 11/08 14:42:09 - mmengine - DEBUG - Get class `ResNet` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - An `ResNet` instance is built from registry, and its implementation can be found in mmdet.models.backbones.resnet
# 11/08 14:42:09 - mmengine - DEBUG - Get class `FPN` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:09 - mmengine - DEBUG - An `FPN` instance is built from registry, and its implementation can be found in mmdet.models.necks.fpn
# 11/08 14:42:09 - mmengine - DEBUG - Get class `RPNHead` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - Modules of mmdet's task util registry have been automatically imported from mmdet.models
# 11/08 14:42:09 - mmengine - DEBUG - Get class `DeltaXYWHBBoxCoder` from "task util" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `DeltaXYWHBBoxCoder` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.coders.delta_xywh_bbox_coder
# 11/08 14:42:09 - mmengine - DEBUG - Get class `CrossEntropyLoss` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `CrossEntropyLoss` instance is built from registry, and its implementation can be found in mmdet.models.losses.cross_entropy_loss
# 11/08 14:42:09 - mmengine - DEBUG - Get class `L1Loss` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `L1Loss` instance is built from registry, and its implementation can be found in mmdet.models.losses.smooth_l1_loss
# 11/08 14:42:09 - mmengine - DEBUG - Get class `MaxIoUAssigner` from "task util" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `BboxOverlaps2D` from "task util" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `BboxOverlaps2D` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.assigners.iou2d_calculator
# 11/08 14:42:09 - mmengine - DEBUG - An `MaxIoUAssigner` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.assigners.max_iou_assigner
# 11/08 14:42:09 - mmengine - DEBUG - Get class `RandomSampler` from "task util" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `RandomSampler` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.samplers.random_sampler
# 11/08 14:42:09 - mmengine - DEBUG - Get class `AnchorGenerator` from "task util" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `AnchorGenerator` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.prior_generators.anchor_generator
# 11/08 14:42:09 - mmengine - DEBUG - An `RPNHead` instance is built from registry, and its implementation can be found in mmdet.models.dense_heads.rpn_head
# 11/08 14:42:09 - mmengine - DEBUG - Get class `StandardRoIHead` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `SingleRoIExtractor` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `SingleRoIExtractor` instance is built from registry, and its implementation can be found in mmdet.models.roi_heads.roi_extractors.single_level_roi_extractor
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Shared2FCBBoxHead` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - Get class `DeltaXYWHBBoxCoder` from "task util" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `DeltaXYWHBBoxCoder` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.coders.delta_xywh_bbox_coder
# 11/08 14:42:09 - mmengine - DEBUG - Get class `CrossEntropyLoss` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `CrossEntropyLoss` instance is built from registry, and its implementation can be found in mmdet.models.losses.cross_entropy_loss
# 11/08 14:42:09 - mmengine - DEBUG - Get class `L1Loss` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `L1Loss` instance is built from registry, and its implementation can be found in mmdet.models.losses.smooth_l1_loss
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Linear` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `Linear` instance is built from registry, and its implementation can be found in torch.nn.modules.linear
# 11/08 14:42:09 - mmengine - DEBUG - Get class `Linear` from "model" registry in "mmdet"
# 11/08 14:42:09 - mmengine - DEBUG - An `Linear` instance is built from registry, and its implementation can be found in torch.nn.modules.linear
# 11/08 14:42:10 - mmengine - DEBUG - Get class `Linear` from "model" registry in "mmdet"
# 11/08 14:42:10 - mmengine - DEBUG - An `Linear` instance is built from registry, and its implementation can be found in torch.nn.modules.linear
# 11/08 14:42:10 - mmengine - DEBUG - Get class `Linear` from "model" registry in "mmdet"
# 11/08 14:42:10 - mmengine - DEBUG - An `Linear` instance is built from registry, and its implementation can be found in torch.nn.modules.linear
# 11/08 14:42:10 - mmengine - DEBUG - An `Shared2FCBBoxHead` instance is built from registry, and its implementation can be found in mmdet.models.roi_heads.bbox_heads.convfc_bbox_head
# 11/08 14:42:10 - mmengine - DEBUG - Get class `SingleRoIExtractor` from "model" registry in "mmdet"
# 11/08 14:42:10 - mmengine - DEBUG - An `SingleRoIExtractor` instance is built from registry, and its implementation can be found in mmdet.models.roi_heads.roi_extractors.single_level_roi_extractor
# 11/08 14:42:10 - mmengine - DEBUG - Get class `FCNMaskHead` from "model" registry in "mmdet"
# 11/08 14:42:10 - mmengine - DEBUG - Get class `CrossEntropyLoss` from "model" registry in "mmdet"
# 11/08 14:42:10 - mmengine - DEBUG - An `CrossEntropyLoss` instance is built from registry, and its implementation can be found in mmdet.models.losses.cross_entropy_loss
# 11/08 14:42:10 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:10 - mmengine - DEBUG - Get class `ReLU` from "model" registry in "mmengine"
# 11/08 14:42:10 - mmengine - DEBUG - An `ReLU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 11/08 14:42:10 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:10 - mmengine - DEBUG - Get class `ReLU` from "model" registry in "mmengine"
# 11/08 14:42:10 - mmengine - DEBUG - An `ReLU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 11/08 14:42:10 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:10 - mmengine - DEBUG - Get class `ReLU` from "model" registry in "mmengine"
# 11/08 14:42:10 - mmengine - DEBUG - An `ReLU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 11/08 14:42:10 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:10 - mmengine - DEBUG - Get class `ReLU` from "model" registry in "mmengine"
# 11/08 14:42:10 - mmengine - DEBUG - An `ReLU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 11/08 14:42:10 - mmengine - DEBUG - Get class `ConvTranspose2d` from "model" registry in "mmengine"
# 11/08 14:42:10 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:42:10 - mmengine - DEBUG - An `FCNMaskHead` instance is built from registry, and its implementation can be found in mmdet.models.roi_heads.mask_heads.fcn_mask_head
# 11/08 14:42:10 - mmengine - DEBUG - Get class `MaxIoUAssigner` from "task util" registry in "mmdet"
# 11/08 14:42:10 - mmengine - DEBUG - Get class `BboxOverlaps2D` from "task util" registry in "mmdet"
# 11/08 14:42:10 - mmengine - DEBUG - An `BboxOverlaps2D` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.assigners.iou2d_calculator
# 11/08 14:42:10 - mmengine - DEBUG - An `MaxIoUAssigner` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.assigners.max_iou_assigner
# 11/08 14:42:10 - mmengine - DEBUG - Get class `RandomSampler` from "task util" registry in "mmdet"
# 11/08 14:42:10 - mmengine - DEBUG - An `RandomSampler` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.samplers.random_sampler
# 11/08 14:42:10 - mmengine - DEBUG - An `StandardRoIHead` instance is built from registry, and its implementation can be found in mmdet.models.roi_heads.standard_roi_head
# 11/08 14:42:10 - mmengine - DEBUG - An `MaskRCNN` instance is built from registry, and its implementation can be found in mmdet.models.detectors.mask_rcnn
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# 11/08 14:42:13 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/08 14:42:13 - mmengine - DEBUG - Modules of mmdet's hook registry have been automatically imported from mmdet.engine.hooks
# 11/08 14:42:13 - mmengine - DEBUG - Get class `RuntimeInfoHook` from "hook" registry in "mmengine"
# 11/08 14:42:13 - mmengine - DEBUG - An `RuntimeInfoHook` instance is built from registry, and its implementation can be found in mmengine.hooks.runtime_info_hook
# 11/08 14:42:13 - mmengine - DEBUG - Get class `IterTimerHook` from "hook" registry in "mmengine"
# 11/08 14:42:13 - mmengine - DEBUG - An `IterTimerHook` instance is built from registry, and its implementation can be found in mmengine.hooks.iter_timer_hook
# 11/08 14:42:13 - mmengine - DEBUG - Get class `DistSamplerSeedHook` from "hook" registry in "mmengine"
# 11/08 14:42:13 - mmengine - DEBUG - An `DistSamplerSeedHook` instance is built from registry, and its implementation can be found in mmengine.hooks.sampler_seed_hook
# 11/08 14:42:13 - mmengine - DEBUG - Get class `LoggerHook` from "hook" registry in "mmengine"
# 11/08 14:42:13 - mmengine - DEBUG - An `LoggerHook` instance is built from registry, and its implementation can be found in mmengine.hooks.logger_hook
# 11/08 14:42:13 - mmengine - DEBUG - Get class `ParamSchedulerHook` from "hook" registry in "mmengine"
# 11/08 14:42:13 - mmengine - DEBUG - An `ParamSchedulerHook` instance is built from registry, and its implementation can be found in mmengine.hooks.param_scheduler_hook
# 11/08 14:42:13 - mmengine - DEBUG - Get class `CheckpointHook` from "hook" registry in "mmengine"
# 11/08 14:42:13 - mmengine - DEBUG - An `CheckpointHook` instance is built from registry, and its implementation can be found in mmengine.hooks.checkpoint_hook
# 11/08 14:42:13 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# 11/08 14:42:14 - mmengine - DEBUG - Modules of mmdet's loop registry have been automatically imported from mmdet.engine.runner
# 11/08 14:42:14 - mmengine - DEBUG - Get class `TestLoop` from "loop" registry in "mmengine"
# 11/08 14:42:14 - mmengine - DEBUG - Modules of mmdet's dataset registry have been automatically imported from mmdet.datasets
# 11/08 14:42:14 - mmengine - DEBUG - Get class `CocoDataset` from "dataset" registry in "mmdet"
# 11/08 14:42:14 - mmengine - DEBUG - Modules of mmdet's transform registry have been automatically imported from mmdet.datasets.transforms
# 11/08 14:42:14 - mmengine - DEBUG - Get class `LoadImageFromFile` from "transform" registry in "mmengine"
# 11/08 14:42:14 - mmengine - DEBUG - An `LoadImageFromFile` instance is built from registry, and its implementation can be found in mmcv.transforms.loading
# 11/08 14:42:14 - mmengine - DEBUG - Get class `Resize` from "transform" registry in "mmdet"
# 11/08 14:42:14 - mmengine - DEBUG - An `Resize` instance is built from registry, and its implementation can be found in mmdet.datasets.transforms.transforms
# 11/08 14:42:14 - mmengine - DEBUG - Get class `LoadAnnotations` from "transform" registry in "mmdet"
# 11/08 14:42:14 - mmengine - DEBUG - An `LoadAnnotations` instance is built from registry, and its implementation can be found in mmdet.datasets.transforms.loading
# 11/08 14:42:14 - mmengine - DEBUG - Get class `PackDetInputs` from "transform" registry in "mmdet"
# 11/08 14:42:14 - mmengine - DEBUG - An `PackDetInputs` instance is built from registry, and its implementation can be found in mmdet.datasets.transforms.formatting
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# 11/08 14:42:15 - mmengine - DEBUG - An `CocoDataset` instance is built from registry, and its implementation can be found in mmdet.datasets.coco
# 11/08 14:42:15 - mmengine - DEBUG - Modules of mmdet's data sampler registry have been automatically imported from mmdet.datasets.samplers
# 11/08 14:42:15 - mmengine - DEBUG - Get class `DefaultSampler` from "data sampler" registry in "mmengine"
# 11/08 14:42:15 - mmengine - DEBUG - An `DefaultSampler` instance is built from registry, and its implementation can be found in mmengine.dataset.sampler
# 11/08 14:42:15 - mmengine - DEBUG - Get class `pseudo_collate` from "function" registry in "mmengine"
# 11/08 14:42:15 - mmengine - DEBUG - Modules of mmdet's metric registry have been automatically imported from mmdet.evaluation
# 11/08 14:42:15 - mmengine - DEBUG - Get class `CocoMetric` from "metric" registry in "mmdet"
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# 11/08 14:42:15 - mmengine - DEBUG - An `CocoMetric` instance is built from registry, and its implementation can be found in mmdet.evaluation.metrics.coco_metric
# 11/08 14:42:15 - mmengine - DEBUG - An `TestLoop` instance is built from registry, and its implementation can be found in mmengine.runner.loops
# Loads checkpoint by local backend from path: /root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/model_data/epoch_90.pth
# 11/08 14:42:17 - mmengine - INFO - Load checkpoint from /root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/model_data/epoch_90.pth
# /root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 11/08 14:42:22 - mmengine - INFO - Epoch(test) [1/3]    eta: 0:00:11  time: 5.6790  data_time: 4.3895  memory: 3197
# 11/08 14:42:29 - mmengine - INFO - Epoch(test) [2/3]    eta: 0:00:06  time: 7.0930  data_time: 5.8882  memory: 3212
# 11/08 14:42:36 - mmengine - INFO - Epoch(test) [3/3]    eta: 0:00:00  time: 6.9257  data_time: 5.6760  memory: 3385
# 11/08 14:42:36 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=7.04s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 11/08 14:42:43 - mmengine - INFO - bbox_mAP_copypaste: 0.008 0.021 0.006 0.008 0.003 -1.000
# 11/08 14:42:43 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=8.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 11/08 14:42:51 - mmengine - INFO - segm_mAP_copypaste: 0.008 0.021 0.006 0.008 0.008 -1.000
# 11/08 14:42:51 - mmengine - INFO - Epoch(test) [3/3]    coco/bbox_mAP: 0.0080  coco/bbox_mAP_50: 0.0210  coco/bbox_mAP_75: 0.0060  coco/bbox_mAP_s: 0.0080  coco/bbox_mAP_m: 0.0030  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.0080  coco/segm_mAP_50: 0.0210  coco/segm_mAP_75: 0.0060  coco/segm_mAP_s: 0.0080  coco/segm_mAP_m: 0.0080  coco/segm_mAP_l: -1.0000  data_time: 5.3179  time: 6.5659
# wandb: Waiting for W&B process to finish... (success).
# ^C
# wandb: ERROR Control-C detected -- Run data was not synced

# %%
# !python test.py
# Out:
# 11/08 14:45:41 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 2099879118
#     GPU 0: NVIDIA RTX A5000
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.1, V11.1.105
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.9.0+cu111
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.1.2 (Git Hash 98be7e8afa711dc9b66c8ff3504129cb82013cdb)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.1
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.0.5
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.9.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.10.0+cu111
#     OpenCV: 4.7.0
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/08 14:45:42 - mmengine - INFO - Config:
# model = dict(
#     type='MaskRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=False,
#         pad_mask=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=4,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#         mask_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=14, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         mask_head=dict(
#             type='FCNMaskHead',
#             num_convs=4,
#             in_channels=256,
#             conv_out_channels=256,
#             num_classes=4,
#             loss_mask=dict(
#                 type='CrossEntropyLoss', use_mask=True, loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             mask_size=28,
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=2000,
#             max_per_img=1500,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=1000,
#             mask_thr_binary=0.5)))
# dataset_type = 'CocoDataset'
# data_root = '/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/'
# metainfo = dict(
#     classes=('Inflammatory', 'Healthy_epithelial', 'Epithelial',
#              'Spindle-shaped'),
#     palette=[(120, 120, 60), (20, 120, 160), (72, 100, 60), (111, 67, 60)])
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(256, 256)),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=4,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/',
#         metainfo=dict(
#             classes=('Inflammatory', 'Healthy_epithelial', 'Epithelial',
#                      'Spindle-shaped'),
#             palette=[(120, 120, 60), (20, 120, 160), (72, 100, 60),
#                      (111, 67, 60)]),
#         ann_file='Train/annotations.json',
#         data_prefix=dict(img='Train/Images/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(256, 256)),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackDetInputs')
#         ],
#         backend_args=None))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=1,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/',
#         metainfo=dict(
#             classes=('Inflammatory', 'Healthy_epithelial', 'Epithelial',
#                      'Spindle-shaped'),
#             palette=[(120, 120, 60), (20, 120, 160), (72, 100, 60),
#                      (111, 67, 60)]),
#         ann_file='Test/annotations.json',
#         data_prefix=dict(img='Test/Images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None,
#         indices=3))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=1,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/',
#         metainfo=dict(
#             classes=('Inflammatory', 'Healthy_epithelial', 'Epithelial',
#                      'Spindle-shaped'),
#             palette=[(120, 120, 60), (20, 120, 160), (72, 100, 60),
#                      (111, 67, 60)]),
#         ann_file='Test/annotations.json',
#         data_prefix=dict(img='Test/Images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None,
#         indices=3))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/Test/annotations.json',
#     metric=['bbox', 'segm'],
#     format_only=False,
#     backend_args=None,
#     outfile_prefix=
#     '/root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/work_dirs/test')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/autodl-tmp/pannuke_app/train/datasets/CoNSeP/Test/annotations.json',
#     metric=['bbox', 'segm'],
#     format_only=False,
#     backend_args=None,
#     outfile_prefix=
#     '/root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/work_dirs/test')
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=100, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=40,
#         by_epoch=True,
#         milestones=[8, 11],
#         gamma=0.1)
# ]
# optim_wrapper = dict(
#     type='OptimWrapper', optimizer=dict(type='Adam', lr=0.001))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=1),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='WandbVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='WandbVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=1, by_epoch=True)
# log_level = 'DEBUG'
# load_from = '/root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/model_data/epoch_90.pth'
# resume = False
# evaluation = dict(
#     interval=1, metric='bbox', options=dict(maxDets=[100, 300, 1000]))
# launcher = 'none'
# work_dir = './work_dirs/consep_config'
#
# 11/08 14:45:42 - mmengine - DEBUG - Modules of mmdet's visualizer registry have been automatically imported from mmdet.visualization
# 11/08 14:45:42 - mmengine - DEBUG - Get class `DetLocalVisualizer` from "visualizer" registry in "mmdet"
# 11/08 14:45:42 - mmengine - DEBUG - Modules of mmdet's vis_backend registry have been automatically imported from mmdet.visualization
# 11/08 14:45:42 - mmengine - DEBUG - Get class `WandbVisBackend` from "vis_backend" registry in "mmengine"
# 11/08 14:45:42 - mmengine - DEBUG - An `WandbVisBackend` instance is built from registry, and its implementation can be found in mmengine.visualization.vis_backend
# 11/08 14:45:43 - mmengine - DEBUG - An `DetLocalVisualizer` instance is built from registry, and its implementation can be found in mmdet.visualization.local_visualizer
# 11/08 14:45:43 - mmengine - DEBUG - Attribute `_env_initialized` is not defined in <class 'mmengine.visualization.vis_backend.WandbVisBackend'> or `<class 'mmengine.visualization.vis_backend.WandbVisBackend'>._env_initialized is False, `_init_env` will be called and <class 'mmengine.visualization.vis_backend.WandbVisBackend'>._env_initialized will be set to True
# wandb: Currently logged in as: weifeiouyang (weifei). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/work_dirs/consep_config/20231108_144541/vis_data/wandb/run-20231108_144545-l7svnn6n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run true-frog-20
# wandb: ⭐️ View project at https://wandb.ai/weifei/pannuke_app-train_mask_rcnn_consep
# wandb: 🚀 View run at https://wandb.ai/weifei/pannuke_app-train_mask_rcnn_consep/runs/l7svnn6n
# 11/08 14:45:48 - mmengine - DEBUG - Modules of mmdet's model registry have been automatically imported from mmdet.models
# 11/08 14:45:48 - mmengine - DEBUG - Get class `MaskRCNN` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `DetDataPreprocessor` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `DetDataPreprocessor` instance is built from registry, and its implementation can be found in mmdet.models.data_preprocessors.data_preprocessor
# 11/08 14:45:48 - mmengine - DEBUG - Get class `ResNet` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BatchNorm2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - An `ResNet` instance is built from registry, and its implementation can be found in mmdet.models.backbones.resnet
# 11/08 14:45:48 - mmengine - DEBUG - Get class `FPN` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - An `FPN` instance is built from registry, and its implementation can be found in mmdet.models.necks.fpn
# 11/08 14:45:48 - mmengine - DEBUG - Get class `RPNHead` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - Modules of mmdet's task util registry have been automatically imported from mmdet.models
# 11/08 14:45:48 - mmengine - DEBUG - Get class `DeltaXYWHBBoxCoder` from "task util" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `DeltaXYWHBBoxCoder` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.coders.delta_xywh_bbox_coder
# 11/08 14:45:48 - mmengine - DEBUG - Get class `CrossEntropyLoss` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `CrossEntropyLoss` instance is built from registry, and its implementation can be found in mmdet.models.losses.cross_entropy_loss
# 11/08 14:45:48 - mmengine - DEBUG - Get class `L1Loss` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `L1Loss` instance is built from registry, and its implementation can be found in mmdet.models.losses.smooth_l1_loss
# 11/08 14:45:48 - mmengine - DEBUG - Get class `MaxIoUAssigner` from "task util" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BboxOverlaps2D` from "task util" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `BboxOverlaps2D` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.assigners.iou2d_calculator
# 11/08 14:45:48 - mmengine - DEBUG - An `MaxIoUAssigner` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.assigners.max_iou_assigner
# 11/08 14:45:48 - mmengine - DEBUG - Get class `RandomSampler` from "task util" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `RandomSampler` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.samplers.random_sampler
# 11/08 14:45:48 - mmengine - DEBUG - Get class `AnchorGenerator` from "task util" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `AnchorGenerator` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.prior_generators.anchor_generator
# 11/08 14:45:48 - mmengine - DEBUG - An `RPNHead` instance is built from registry, and its implementation can be found in mmdet.models.dense_heads.rpn_head
# 11/08 14:45:48 - mmengine - DEBUG - Get class `StandardRoIHead` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `SingleRoIExtractor` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `SingleRoIExtractor` instance is built from registry, and its implementation can be found in mmdet.models.roi_heads.roi_extractors.single_level_roi_extractor
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Shared2FCBBoxHead` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `DeltaXYWHBBoxCoder` from "task util" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `DeltaXYWHBBoxCoder` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.coders.delta_xywh_bbox_coder
# 11/08 14:45:48 - mmengine - DEBUG - Get class `CrossEntropyLoss` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `CrossEntropyLoss` instance is built from registry, and its implementation can be found in mmdet.models.losses.cross_entropy_loss
# 11/08 14:45:48 - mmengine - DEBUG - Get class `L1Loss` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `L1Loss` instance is built from registry, and its implementation can be found in mmdet.models.losses.smooth_l1_loss
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Linear` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `Linear` instance is built from registry, and its implementation can be found in torch.nn.modules.linear
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Linear` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `Linear` instance is built from registry, and its implementation can be found in torch.nn.modules.linear
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Linear` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `Linear` instance is built from registry, and its implementation can be found in torch.nn.modules.linear
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Linear` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `Linear` instance is built from registry, and its implementation can be found in torch.nn.modules.linear
# 11/08 14:45:48 - mmengine - DEBUG - An `Shared2FCBBoxHead` instance is built from registry, and its implementation can be found in mmdet.models.roi_heads.bbox_heads.convfc_bbox_head
# 11/08 14:45:48 - mmengine - DEBUG - Get class `SingleRoIExtractor` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `SingleRoIExtractor` instance is built from registry, and its implementation can be found in mmdet.models.roi_heads.roi_extractors.single_level_roi_extractor
# 11/08 14:45:48 - mmengine - DEBUG - Get class `FCNMaskHead` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `CrossEntropyLoss` from "model" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `CrossEntropyLoss` instance is built from registry, and its implementation can be found in mmdet.models.losses.cross_entropy_loss
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `ReLU` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - An `ReLU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `ReLU` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - An `ReLU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `ReLU` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - An `ReLU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `ReLU` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - An `ReLU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 11/08 14:45:48 - mmengine - DEBUG - Get class `ConvTranspose2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 11/08 14:45:48 - mmengine - DEBUG - An `FCNMaskHead` instance is built from registry, and its implementation can be found in mmdet.models.roi_heads.mask_heads.fcn_mask_head
# 11/08 14:45:48 - mmengine - DEBUG - Get class `MaxIoUAssigner` from "task util" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - Get class `BboxOverlaps2D` from "task util" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `BboxOverlaps2D` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.assigners.iou2d_calculator
# 11/08 14:45:48 - mmengine - DEBUG - An `MaxIoUAssigner` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.assigners.max_iou_assigner
# 11/08 14:45:48 - mmengine - DEBUG - Get class `RandomSampler` from "task util" registry in "mmdet"
# 11/08 14:45:48 - mmengine - DEBUG - An `RandomSampler` instance is built from registry, and its implementation can be found in mmdet.models.task_modules.samplers.random_sampler
# 11/08 14:45:48 - mmengine - DEBUG - An `StandardRoIHead` instance is built from registry, and its implementation can be found in mmdet.models.roi_heads.standard_roi_head
# 11/08 14:45:48 - mmengine - DEBUG - An `MaskRCNN` instance is built from registry, and its implementation can be found in mmdet.models.detectors.mask_rcnn
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# 11/08 14:45:51 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/08 14:45:51 - mmengine - DEBUG - Modules of mmdet's hook registry have been automatically imported from mmdet.engine.hooks
# 11/08 14:45:51 - mmengine - DEBUG - Get class `RuntimeInfoHook` from "hook" registry in "mmengine"
# 11/08 14:45:51 - mmengine - DEBUG - An `RuntimeInfoHook` instance is built from registry, and its implementation can be found in mmengine.hooks.runtime_info_hook
# 11/08 14:45:51 - mmengine - DEBUG - Get class `IterTimerHook` from "hook" registry in "mmengine"
# 11/08 14:45:51 - mmengine - DEBUG - An `IterTimerHook` instance is built from registry, and its implementation can be found in mmengine.hooks.iter_timer_hook
# 11/08 14:45:51 - mmengine - DEBUG - Get class `DistSamplerSeedHook` from "hook" registry in "mmengine"
# 11/08 14:45:51 - mmengine - DEBUG - An `DistSamplerSeedHook` instance is built from registry, and its implementation can be found in mmengine.hooks.sampler_seed_hook
# 11/08 14:45:51 - mmengine - DEBUG - Get class `LoggerHook` from "hook" registry in "mmengine"
# 11/08 14:45:51 - mmengine - DEBUG - An `LoggerHook` instance is built from registry, and its implementation can be found in mmengine.hooks.logger_hook
# 11/08 14:45:51 - mmengine - DEBUG - Get class `ParamSchedulerHook` from "hook" registry in "mmengine"
# 11/08 14:45:51 - mmengine - DEBUG - An `ParamSchedulerHook` instance is built from registry, and its implementation can be found in mmengine.hooks.param_scheduler_hook
# 11/08 14:45:51 - mmengine - DEBUG - Get class `CheckpointHook` from "hook" registry in "mmengine"
# 11/08 14:45:51 - mmengine - DEBUG - An `CheckpointHook` instance is built from registry, and its implementation can be found in mmengine.hooks.checkpoint_hook
# 11/08 14:45:51 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 11/08 14:45:52 - mmengine - DEBUG - Modules of mmdet's loop registry have been automatically imported from mmdet.engine.runner
# 11/08 14:45:52 - mmengine - DEBUG - Get class `TestLoop` from "loop" registry in "mmengine"
# 11/08 14:45:52 - mmengine - DEBUG - Modules of mmdet's dataset registry have been automatically imported from mmdet.datasets
# 11/08 14:45:52 - mmengine - DEBUG - Get class `CocoDataset` from "dataset" registry in "mmdet"
# 11/08 14:45:52 - mmengine - DEBUG - Modules of mmdet's transform registry have been automatically imported from mmdet.datasets.transforms
# 11/08 14:45:52 - mmengine - DEBUG - Get class `LoadImageFromFile` from "transform" registry in "mmengine"
# 11/08 14:45:52 - mmengine - DEBUG - An `LoadImageFromFile` instance is built from registry, and its implementation can be found in mmcv.transforms.loading
# 11/08 14:45:52 - mmengine - DEBUG - Get class `Resize` from "transform" registry in "mmdet"
# 11/08 14:45:52 - mmengine - DEBUG - An `Resize` instance is built from registry, and its implementation can be found in mmdet.datasets.transforms.transforms
# 11/08 14:45:52 - mmengine - DEBUG - Get class `LoadAnnotations` from "transform" registry in "mmdet"
# 11/08 14:45:52 - mmengine - DEBUG - An `LoadAnnotations` instance is built from registry, and its implementation can be found in mmdet.datasets.transforms.loading
# 11/08 14:45:52 - mmengine - DEBUG - Get class `PackDetInputs` from "transform" registry in "mmdet"
# 11/08 14:45:52 - mmengine - DEBUG - An `PackDetInputs` instance is built from registry, and its implementation can be found in mmdet.datasets.transforms.formatting
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 11/08 14:45:52 - mmengine - DEBUG - An `CocoDataset` instance is built from registry, and its implementation can be found in mmdet.datasets.coco
# 11/08 14:45:52 - mmengine - DEBUG - Modules of mmdet's data sampler registry have been automatically imported from mmdet.datasets.samplers
# 11/08 14:45:52 - mmengine - DEBUG - Get class `DefaultSampler` from "data sampler" registry in "mmengine"
# 11/08 14:45:52 - mmengine - DEBUG - An `DefaultSampler` instance is built from registry, and its implementation can be found in mmengine.dataset.sampler
# 11/08 14:45:52 - mmengine - DEBUG - Get class `pseudo_collate` from "function" registry in "mmengine"
# 11/08 14:45:52 - mmengine - DEBUG - Modules of mmdet's metric registry have been automatically imported from mmdet.evaluation
# 11/08 14:45:52 - mmengine - DEBUG - Get class `CocoMetric` from "metric" registry in "mmdet"
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 11/08 14:45:52 - mmengine - DEBUG - An `CocoMetric` instance is built from registry, and its implementation can be found in mmdet.evaluation.metrics.coco_metric
# 11/08 14:45:52 - mmengine - DEBUG - An `TestLoop` instance is built from registry, and its implementation can be found in mmengine.runner.loops
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# wandb: Network error (TransientError), entering retry loop.
# Loads checkpoint by local backend from path: /root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/model_data/epoch_90.pth
# 11/08 14:45:54 - mmengine - INFO - Load checkpoint from /root/autodl-tmp/pannuke_app/train/mask_rcnn/consep/model_data/epoch_90.pth
# /root/miniconda3/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 11/08 14:45:59 - mmengine - INFO - Epoch(test) [1/3]    eta: 0:00:11  time: 5.5063  data_time: 4.4717  memory: 3197
# 11/08 14:46:07 - mmengine - INFO - Epoch(test) [2/3]    eta: 0:00:06  time: 8.0326  data_time: 7.0442  memory: 3212
# 11/08 14:46:14 - mmengine - INFO - Epoch(test) [3/3]    eta: 0:00:00  time: 7.0543  data_time: 5.8469  memory: 3385
# 11/08 14:46:14 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=7.80s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 11/08 14:46:22 - mmengine - INFO - bbox_mAP_copypaste: 0.008 0.021 0.006 0.008 0.003 -1.000
# 11/08 14:46:22 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=8.10s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 11/08 14:46:30 - mmengine - INFO - segm_mAP_copypaste: 0.008 0.021 0.006 0.008 0.008 -1.000
# 11/08 14:46:30 - mmengine - INFO - Epoch(test) [3/3]    coco/bbox_mAP: 0.0080  coco/bbox_mAP_50: 0.0210  coco/bbox_mAP_75: 0.0060  coco/bbox_mAP_s: 0.0080  coco/bbox_mAP_m: 0.0030  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.0080  coco/segm_mAP_50: 0.0210  coco/segm_mAP_75: 0.0060  coco/segm_mAP_s: 0.0080  coco/segm_mAP_m: 0.0080  coco/segm_mAP_l: -1.0000  data_time: 5.7876  time: 6.8644
# wandb: Waiting for W&B process to finish... (success).
